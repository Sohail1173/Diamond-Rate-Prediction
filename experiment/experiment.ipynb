# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# %pip  install seaborn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scikit-learn in c:\users\91808\downloads\diamond-rate-prediction\myenv\lib\site-packages (1.4.2)
# ...
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose  import ColumnTransformer

# %%
df=pd.read_csv(r"C:\Users\91808\Downloads\Diamond-Rate-Prediction\raw.csv")

# %%
X=df.drop(labels=["id","price"],axis=1)
y=df["price"]

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y
# Out:
# 0         13619
# 1         13387
# 2          2772
# 3           666
# 4         14453
#           ...
# 193568     1130
# 193569     2874
# 193570     3036
# 193571      681
# 193572     2258
# Name: price, Length: 193573, dtype: int64

# %%
X.info(
    
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    193573 non-null  float64
#  1   cut      193573 non-null  object
#  2   color    193573 non-null  object
#  3   clarity  193573 non-null  object
#  4   depth    193573 non-null  float64
#  5   table    193573 non-null  float64
#  6   x        193573 non-null  float64
#  7   y        193573 non-null  float64
#  8   z        193573 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 13.3+ MB

# %%
X.select_dtypes(include="object")
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
X.select_dtypes(exclude="object")
# Out:
#         carat  depth  table     x     y     z
# 0        1.52   62.2   58.0  7.27  7.33  4.55
# 1        2.03   62.0   58.0  8.06  8.12  5.05
# 2        0.70   61.2   57.0  5.69  5.73  3.50
# 3        0.32   61.6   56.0  4.38  4.41  2.71
# 4        1.70   62.6   59.0  7.65  7.61  4.77
# ...       ...    ...    ...   ...   ...   ...
# 193568   0.31   61.1   56.0  4.35  4.39  2.67
# 193569   0.70   60.3   58.0  5.75  5.77  3.47
# 193570   0.73   63.1   57.0  5.72  5.75  3.62
# 193571   0.34   62.9   55.0  4.45  4.49  2.81
# 193572   0.71   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 6 columns]

# %%
# cat_cols=[feature for feature in data.columns if data[feature].dtypes=="object"]
# num_cols=[feature for feature in data.columns if data[feature].dtypes!="object"]
cat_cols=X.select_dtypes(include="object").columns

num_cols=X.select_dtypes(exclude="object").columns

# %%
cat_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
num_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.select_dtypes(include="object").head()
# Out:
#          cut color clarity
# 0    Premium     F     VS2
# 1  Very Good     J     SI2
# 2      Ideal     G     VS1
# 3      Ideal     G     VS1
# 4    Premium     G     VS2

# %%
X["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
cut_categories = ['Fair', 'Good', 'Very Good','Premium','Ideal']
color_categories=['D', 'E', 'F', 'G', 'H', 'I', 'J']
clarity_categories=['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']

# %%
num_pipeline=Pipeline(
    steps=[
        ("imputer",SimpleImputer()),
        ("scaler",StandardScaler())
    ]
)

# %%
cat_pipeline=Pipeline(

    steps=[
        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("ordinalencoder",OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories]))

    ]
)

# %%
num_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
cat_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
preprocessor=ColumnTransformer(

    [
        ("num_pipeline",num_pipeline,num_cols),
        ("cat_pipeline",cat_pipeline,cat_cols)
    ]
)

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y
# Out:
# 0         13619
# 1         13387
# 2          2772
# 3           666
# 4         14453
#           ...
# 193568     1130
# 193569     2874
# 193570     3036
# 193571      681
# 193572     2258
# Name: price, Length: 193573, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30, random_state=42)

# %%
X_test.shape
# Out:
# (58072, 9)

# %%
y_train.head(
    
)
# Out:
# 11504      1181
# 95284      7418
# 184777    12755
# 5419       1020
# 45466       445
# Name: price, dtype: int64

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-0.82314374, -1.12998781, -0.64189666, ...,  4.        ,
#          1.        ,  5.        ],
#        [ 0.94502267, -1.77782269,  0.92190185, ...,  2.        ,
#          4.        ,  4.        ],
#        [ 1.9584839 ,  0.16568195,  0.40063568, ...,  3.        ,
#          4.        ,  3.        ],
#        ...,
#        [ 0.92345966,  0.90606467,  0.40063568, ...,  3.        ,
#          3.        ,  3.        ],
#        [-1.03877378, -0.66724861, -0.64189666, ...,  2.        ,
#          3.        ,  6.        ],
#        [-1.03877378, -0.01941373,  0.92190185, ...,  2.        ,
#          3.        ,  1.        ]])

# %%
preprocessor.transform(X_test)
# Out:
# array([[-0.62907669,  0.25822979, -0.12063049, ...,  4.        ,
#          0.        ,  2.        ],
#        [ 2.60537405, -2.14801405, -0.12063049, ...,  2.        ,
#          3.        ,  1.        ],
#        [-1.1250258 , -1.22253565,  0.92190185, ...,  3.        ,
#          1.        ,  6.        ],
#        ...,
#        [-0.82314374, -0.01941373, -0.64189666, ...,  4.        ,
#          3.        ,  6.        ],
#        [ 0.90189666, -0.66724861,  1.44316802, ...,  3.        ,
#          5.        ,  2.        ],
#        [ 0.47063656,  0.90606467, -0.64189666, ...,  2.        ,
#          1.        ,  3.        ]])

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num_pipeline__carat', 'num_pipeline__depth',
#        'num_pipeline__table', 'num_pipeline__x', 'num_pipeline__y',
#        'num_pipeline__z', 'cat_pipeline__cut', 'cat_pipeline__color',
#        'cat_pipeline__clarity'], dtype=object)

# %%
# X_train=pd.DataFrame(proprocessor.fit_transform(X_train),columns=proprocessor.get_feature_names_out())
# X_test=pd.DataFrame(proprocessor.fit_transform(X_test),columns=proprocessor.get_feature_names_out())

X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#         num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 -0.823144            -1.129988            -0.641897
# 1                  0.945023            -1.777823             0.921902
# 2                  1.958484             0.165682             0.400636
# 3                 -0.995648            -0.574701            -0.641897
# 4                 -0.995648             0.258230             0.400636
# ...                     ...                  ...                  ...
# 135496            -0.629077            -1.500179             1.964434
# 135497             2.411307             0.443325             2.485700
# 135498             0.923460             0.906065             0.400636
# 135499            -1.038774            -0.667249            -0.641897
# 135500            -1.038774            -0.019414             0.921902
#
#         num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# ...

# %%
X_test
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                -0.629077             0.258230            -0.120630
# 1                 2.605374            -2.148014            -0.120630
# 2                -1.125026            -1.222536             0.921902
# 3                -1.017211            -0.574701             0.921902
# 4                 0.858771             0.628421            -0.641897
# ...                    ...                  ...                  ...
# 58067             0.255007             0.535873             0.921902
# 58068            -0.607514             0.535873            -0.641897
# 58069            -0.823144            -0.019414            -0.641897
# 58070             0.901897            -0.667249             1.443168
# 58071             0.470637             0.906065            -0.641897
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# ...

# %%
# %pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
models={

    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
    'Randomforest':RandomForestRegressor(),
    'xgboost':XGBRegressor()

}

# %%
trained_model_list=[]
model_list=[]
r2_list=[]

# %%
list(models)
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet', 'Randomforest', 'xgboost']

# %%
for i in range(len(list(models))):

    model=list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# Lasso()
# Ridge()
# ElasticNet()
# RandomForestRegressor()
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
models.keys()
# Out:
# dict_keys(['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet', 'Randomforest', 'xgboost'])

# %%
list(models.values())[1]
# Out:
# Lasso()

# %%
def evaluate_model(true,pred):
    r2=r2_score(true,pred)
    mae=mean_absolute_error(true,pred)
    mse=mean_squared_error(true,pred)
    return r2,mae,mse

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)

    MAE,MSE,R2=evaluate_model(y_test,y_pred)

    print("model training performance",model)
    print("MSE",MSE)
    print("MAE",MAE)
    print("R2 Score",R2)
    r2_list.append(R2)
    print("="*40)
    print("\n")
# Out:
# model training performance LinearRegression()
# MSE 675.0758270067478
# MAE 0.9362906819996047
# R2 Score 1029473.3531156847
# ...
#
#
# model training performance Lasso()
# MSE 676.3788803086726
# MAE 0.9362869215688461
# R2 Score 1029534.1175907081
# ...
#
#
# model training performance Ridge()
# MSE 675.1087261318746
# MAE 0.9362900953347935
# R2 Score 1029482.832981572
# ...
#
#
# model training performance ElasticNet()
# MSE 1051.1722281863017
# MAE 0.8582126162411592
# R2 Score 2291130.057094769
# ...
#
#
# model training performance RandomForestRegressor()
# MSE 310.06939069425584
# MAE 0.9769436722944824
# R2 Score 372565.20299567527
# ...
#
#
# model training performance XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
# ...
